# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.distplot(tips['total_bill'],bins=20,kde = False)
# Out:
# C:\Users\simran.maurya\AppData\Local\Temp\ipykernel_13972\2868528789.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'],bins=20,kde = False)
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.distplot(tips['tip'],bins=20,kde = False)sns.distplot(tips['tip'],bins=20,kde = False)
# Out:
# C:\Users\simran.maurya\AppData\Local\Temp\ipykernel_13972\1956422422.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['tip'],bins=20,kde = False)
# <AxesSubplot:xlabel='tip'>

# %%
sns.distplot(tips['sex'])
# Out:
# C:\Users\simran.maurya\AppData\Local\Temp\ipykernel_13972\2439475807.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['sex'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\simran.maurya\Desktop\DS_Foundation\Python\seaborn_section.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/simran.maurya/Desktop/DS_Foundation/Python/seaborn_section.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> sns.distplot(tips['sex'])
#
# ...

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.distplot(tips['size'],bins=20,kde = False)
# Out:
# C:\Users\simran.maurya\AppData\Local\Temp\ipykernel_13972\3811782741.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['size'],bins=20,kde = False)
# <AxesSubplot:xlabel='size'>

# %%
sns.jointplot(x='total_bill',y='tip', data = tips)

# %%
sns.jointplot(x = 'total_bill', y = 'tip',data = tips,kind = 'hex')

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'reg')

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'kde')

# %%
sns.pairplot(tips,hue = 'smoker')

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# ## Categorical Plots

# %%
sns.barplot(x='day',y='tip',data =tips,estimator = np.sum)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.countplot(x= 'day', data = tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.boxplot(x= 'day' ,y='tip',data =tips, hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x = 'time' , y= 'tip' ,data = tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %%
sns.violinplot(x = 'day', y= 'tip' , data = tips,hue = 'sex',split = True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x = 'time', y= 'total_bill', data = tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
sns.swarmplot(x = 'time', y = 'tip', data = tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %%
sns.swarmplot(x = 'time', y = 'tip', data = tips, color = 'black')
sns.violinplot(x = 'time', y = 'tip', data = tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %%
sns.violinplot(x = 'tip', y = 'sex' , data = tips)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='sex'>

# %% [markdown]
# ## Matrix Plots

# %%
tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tc = tips.corr()
fc = flights.corr()

# %%
tc
fc
# Out:
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000

# %%
sns.heatmap(tc, annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(fc, annot = True)
# Out:
# <AxesSubplot:>

# %%
fp = flights.pivot_table(index = 'month', columns = 'year', values = 'passengers')

# %%
sns.heatmap(fp, linecolor = 'white', linewidth = 1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tp = tips.pivot_table(index = 'day',columns = 'sex', values = ['total_bill', 'tip'])

# %%
tp
# Out:
#            tip           total_bill
# sex       Male    Female       Male     Female
# day
# Thur  2.980333  2.575625  18.714667  16.715312
# Fri   2.693000  2.781111  19.857000  14.145556
# Sat   3.083898  2.801786  20.802542  19.680357
# Sun   3.220345  3.367222  21.887241  19.872222

# %%
sns.heatmap(tp, annot = True)
# Out:
# <AxesSubplot:xlabel='None-sex', ylabel='day'>

# %% [markdown]
# ## Grids

# %%
sns.pairplot(tips)

# %%
g = sns.PairGrid(tips)
g.map_diag(sns.boxplot)
g.map_upper(sns.kdeplot)
g.map_lower(plt.scatter)

# %%
m = sns.FacetGrid(data = tips, col = 'sex', row = 'day')
m.map(sns.kdeplot,'tip')

# %% [markdown]
# ## Regression Plots

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips,col = 'time', hue = 'sex')

# %%
sns.set_style('ticks')
sns.countplot(x = 'smoker', data = tips)
sns.despine()
